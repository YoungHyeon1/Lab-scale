# %%
import numpy as np
from pytorch_tabular import TabularModel
import requests
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder

# %%
test_puuid = 'EgGNjpTVLwAAQvx7MmdU2Q1WnEdRS5LRO_3CnGVGg7Q7iIUlcAGPyzZAY4FAq-IpawccwxYq14ofxg'

# %%
spectator = requests.get(
    'https://kr.api.riotgames.com/lol/spectator/v5/active-games/by-summoner/'
    f'{test_puuid}?api_key={api_key}'
)
print(spectator.json())
# Out:
# {'gameId': 7088714237, 'mapId': 11, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED', 'gameQueueConfigId': 420, 'participants': [{'puuid': 'nCxVPZVgXIX9GlfLCTsiqNs9WsXuGfnP96D9MX1p_pSk4JKxKB6AhXWMu2PpjuUZQoV91gSr0pCA0A', 'teamId': 100, 'spell1Id': 4, 'spell2Id': 14, 'championId': 53, 'profileIconId': 6007, 'riotId': 'ui67#333', 'bot': False, 'summonerId': 't9wsofmNdFWqEErXud--891SG3m0cZpCQCeckcuyYwM0LGN9SzEKlp7TPw', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8351, 8306, 8345, 8347, 8275, 8234, 5007, 5001, 5011], 'perkStyle': 8300, 'perkSubStyle': 8200}}, {'puuid': 'm9EVCDe0j1zaF0rHeOxNaeYuI2flSxqqqAEGzWLpK48vTSd5U4fawMp7NEgqnXI2qrhgmtuRIFeiVQ', 'teamId': 100, 'spell1Id': 11, 'spell2Id': 4, 'championId': 203, 'profileIconId': 709, 'riotId': 'best year#u1234', 'bot': False, 'summonerId': 'ER9IaYtLt82qbn7MUN-Uf987I-1PHtognQivnzm-AAo21SFYR0xwDm2q6A', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8005, 9111, 9104, 8014, 8135, 8143, 5005, 5008, 5001], 'perkStyle': 8000, 'perkSubStyle': 8100}}, {'puuid': 'FnXN6bwjbvhHtHUInC0VgXTWOya1wm4CCS46x7YrdRF5fluXEJ-RpLWbzUrXUlDVrFhxMG_vmpJ3LA', 'teamId': 100, 'spell1Id': 12, 'spell2Id': 4, 'championId': 7, 'profileIconId': 1425, 'riotId': '감정없는사람#1354', 'bot': False, 'summonerId': 'VX9DLqEMQ40JAUqO1XPYtFLdRGzkaK5U-ZO6XW1Y45eWBwI', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8112, 8143, 8138, 8105, 8226, 8237, 5005, 5008, 5011], 'perkStyle': 8100, 'perkSubStyle': 8200}}, {'puuid': 'MBhcECmDaRXdyVivCDjr4xHinXwA2fU4I6OBcM1dKy0Fl-NogcuJ015xnULF7hID3mqaCX1TFfJBmQ', 'teamId': 100, 'spell1Id': 4, 'spell2Id': 12, 'championId': 68, 'profileIconId': 6603, 'riotId': '좌유범#KR1', 'bot': False, 'summonerId': '5Mr6mpHBcSwYBM9onhjIaIB-gpiy8qO_hyR10HlJN7fbFCaQocKpW0tbSA', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8369, 8321, 8313, 8316, 8237, 8224, 5008, 5008, 5011], 'perkStyle': 8300, 'perkSubStyle': 8200}}, {'puuid': 'hkKj2Ca1C-3jw6nhYZY8aRlVxHtLmmPRZOjrzsqPChl5H7fmi4iHbpKPGnoA4R87iQp1xj3O4GY91Q', 'teamId': 100, 'spell1Id': 7, 'spell2Id': 4, 'championId': 222, 'profileIconId': 3838, 'riotId': 'jazz#0607', 'bot': False, 'summonerId': '_IwU5nYnwURaWx9ZNYOcLBwkbi65osajxGJOCf83OouiNt0', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8021, 8009, 9103, 8014, 8236, 8233, 5005, 5008, 5011], 'perkStyle': 8000, 'perkSubStyle': 8200}}, {'puuid': 'VkwVuiqGYtAqZDtqBYlJ-9tSBYtJI4ypB-N3cNys1tId0ip1AkxlYxLfuAtJ9x5Sf-jYulo2BXaGQQ', 'teamId': 200, 'spell1Id': 12, 'spell2Id': 4, 'championId': 112, 'profileIconId': 5707, 'riotId': 'lactea420#KR1', 'bot': False, 'summonerId': '4dJRM0aDN71A5cM7-OG6u_79kwZzlSysmPU3UmEMNCHRmA', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8369, 8304, 8313, 8316, 8236, 8226, 5005, 5008, 5001], 'perkStyle': 8300, 'perkSubStyle': 8200}}, {'puuid': 'xdyjYqEcGSSoSo2FvUyVnHML6Qyax3WymvDzXHpjeJiMy3MbDypUOGdyQ6EajVAiE0IfL-DcG2sJEA', 'teamId': 200, 'spell1Id': 11, 'spell2Id': 6, 'championId': 120, 'profileIconId': 7, 'riotId': 'zhishangqingyun#pcwl', 'bot': False, 'summonerId': 'i9v4O1t4HKu2QbakNfFhWQ_snDhAr1opLKaiFr5SR0HXMO-an3XfO1Lo1w', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8230, 8275, 8234, 8232, 9111, 9105, 5005, 5008, 5001], 'perkStyle': 8200, 'perkSubStyle': 8000}}, {'puuid': 'D83228VDMMiRA8-FAa2bGn6oGLBD6s4wdkyQyezdpOr-0GMeXKu6i84ojXNUFFpzZZff0cRBGoY3jA', 'teamId': 200, 'spell1Id': 4, 'spell2Id': 7, 'championId': 267, 'profileIconId': 6037, 'riotId': '系ぎて ReMaster#Lv15', 'bot': False, 'summonerId': '4SPAJ9s2LMuE-QNCQzLa_kReLjZy6POdiZKhgs7eVLtvP1g', 'gameCustomizationObjects': [], 'perks': {'perkIds': [8214, 8226, 8210, 8236, 8347, 8345, 5007, 5008, 5011], 'perkStyle': 8200, 'perkSubStyle': 8300}}, {'puuid': 'ONU7fxqp5HCSGhWEjh1EuDU95c756IooxL_V6l4XALYan4l0cgkNznKlUFSf8gyPwa59Tsv6y5TYVw', 'teamId': 200, 'spell1Id': 21, 'spell2Id': 4, 'championId': 51, 'profileIconId': 3797, 'riotId': 'Hp Day1#8215', 'bot': False, 'summonerId': 'EAItpYycfZGy5V-45s19zQPUyI0YlTfIS10d_30laHAFnFAbheYLhc_N1Q', 'gameCustomizationObjects': [], 'perks': {'perk ...

# %%
test_data = {
    "gameId": 7089020362,
    "mapId": 11,
    "gameMode": "CLASSIC",
    "gameType": "MATCHED",
    "gameQueueConfigId": 420,
    "participants": [
        {
            "puuid": "DlBras6YxOENEHvmHfRKgV4U8huNdIinFJyGUpZcnD4zTzYd-WvHooAPS5G7hCRfxvHEznTPAN73-g",
            "teamId": 100,
            "spell1Id": 11,
            "spell2Id": 4,
            "championId": 131,
            "profileIconId": 6009,
            "riotId": "HHHHHHHlHHHHHHH#KR1",
            "bot": 'false',
            "summonerId": "Z5bAj4lr8VAgxv_VFisC7ddGMHdPjMgSKuCnp-1XxkR5XYs",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8010,
                    9111,
                    9104,
                    8014,
                    8304,
                    8347,
                    5005,
                    5008,
                    5001
                ],
                "perkStyle": 8000,
                "perkSubStyle": 8300
            }
        },
        {
            "puuid": "CMcwLlX7F5gc6nSFsT_BotHX4p4EOp2oXxElBql4L7Bs8G9sE94yScgTc0LqPntxglpPIj2apoE2nA",
            "teamId": 100,
            "spell1Id": 12,
            "spell2Id": 4,
            "championId": 10,
            "profileIconId": 6504,
            "riotId": "덕후아님#KR1",
            "bot": 'false',
            "summonerId": "6zQm7_Aqhth6EIDgU0YoiXSIpR9s_WIGIUTMu1lcwqLuIWQ",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8021,
                    9101,
                    9104,
                    8299,
                    8444,
                    8451,
                    5005,
                    5008,
                    5001
                ],
                "perkStyle": 8000,
                "perkSubStyle": 8400
            }
        },
        {
            "puuid": "UcObIQL31ZQ7W6fTBQ1tpjU29EVHhaG0YDb-zjirdp4Hju9FMvrwNY34uAf4alCD1OsR2FEBH7FGqA",
            "teamId": 100,
            "spell1Id": 7,
            "spell2Id": 4,
            "championId": 117,
            "profileIconId": 3019,
            "riotId": "매 혹#장 인",
            "bot": 'false',
            "summonerId": "KrLZeGjfsAwR4fW_KI4xaWqjnYVYHsF4uskli9Izxh_suxo",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8214,
                    8226,
                    8210,
                    8237,
                    8345,
                    8347,
                    5008,
                    5008,
                    5001
                ],
                "perkStyle": 8200,
                "perkSubStyle": 8300
            }
        },
        {
            "puuid": "I51a7kq_TbFg1Bs9uumbj-p4KW8I8tlR-9I2yn7kM67sdpqAV5Zskgjy5OLY5nOz_KSy6IiZnt0Q9Q",
            "teamId": 100,
            "spell1Id": 4,
            "spell2Id": 6,
            "championId": 67,
            "profileIconId": 1134,
            "riotId": "땅 콩#땅땅콩콩",
            "bot": 'false',
            "summonerId": "ugcyXqXlef10K5s841nayUb0zjkdIHRBePTOzA6FIj_IRtI",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8021,
                    8009,
                    9104,
                    8014,
                    8451,
                    8429,
                    5005,
                    5008,
                    5001
                ],
                "perkStyle": 8000,
                "perkSubStyle": 8400
            }
        },
        {
            "puuid": "WUUnjfnobJerW0sqBXkB-9qa4szoSDli5E5mrIPMCqWclVecUNdfuNagf1HnY1T6vKafK4rgyurxzA",
            "teamId": 100,
            "spell1Id": 4,
            "spell2Id": 6,
            "championId": 498,
            "profileIconId": 6526,
            "riotId": "상 준#0670",
            "bot": 'false',
            "summonerId": "xJ7Yjk_RHskmhX8WO43BuT6CuYKGAbmvX4MoyLyEgUAY7A",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8021,
                    8009,
                    9103,
                    8014,
                    8304,
                    8345,
                    5005,
                    5008,
                    5001
                ],
                "perkStyle": 8000,
                "perkSubStyle": 8300
            }
        },
        {
            "puuid": "oQYJXfoXcybPDWc5UTgS9xnb-d7vwxF-bRYhWFJlsl3uCykVIsGrqVFFjn4QWnVF_G1fszvg67cmLg",
            "teamId": 200,
            "spell1Id": 12,
            "spell2Id": 4,
            "championId": 41,
            "profileIconId": 4568,
            "riotId": "TEN JInG#KR1",
            "bot": 'false',
            "summonerId": "a3ckjOE3KvGeUyw0l4Js1Yzlu3C-npfxJ1X68j6qjRZvsmw",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8021,
                    9101,
                    9105,
                    8014,
                    8345,
                    8347,
                    5008,
                    5008,
                    5001
                ],
                "perkStyle": 8000,
                "perkSubStyle": 8300
            }
        },
        {
            "puuid": "7-36Av_r3JGPWrLyBaaHt0LDO9Ot6za_i9M72Tb43GXevthphpppw-T77Wrv_cvREa7-B0MgIqnHBQ",
            "teamId": 200,
            "spell1Id": 11,
            "spell2Id": 4,
            "championId": 163,
            "profileIconId": 3887,
            "riotId": "진라면순한맛12#KR1",
            "bot": 'false',
            "summonerId": "c7swx1HIqkEPxfCuVQ-DMjFPJ7nCHsqBPFhmwI5-XvaWYg",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8128,
                    8126,
                    8138,
                    8135,
                    8304,
                    8347,
                    5008,
                    5008,
                    5001
                ],
                "perkStyle": 8100,
                "perkSubStyle": 8300
            }
        },
        {
            "puuid": "VO5n9m0aRUkhO7gSnW-8vXXx3xhxGf4ES2KLJG3xA_nCPoDbgzN3Gd1rz_WtaEs1BeKn_oOK98jcIQ",
            "teamId": 200,
            "spell1Id": 12,
            "spell2Id": 4,
            "championId": 84,
            "profileIconId": 4075,
            "riotId": "백크 요종도#KR1",
            "bot": 'false',
            "summonerId": "N1SlCIq7pFzKz5qAiEyEiVmdXmxnh_Mn8IAgg1DeIifMRQlBOVb6cWnnQQ",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8112,
                    8143,
                    8138,
                    8106,
                    8451,
                    8444,
                    5008,
                    5008,
                    5001
                ],
                "perkStyle": 8100,
                "perkSubStyle": 8400
            }
        },
        {
            "puuid": "SYyZ4tDnt3vt_Q7SffHnEo0XrgAEYlkb_Qeze4Y8GejweKjG_OFzjbRuqGs-5aYn_YUuq0oA4Z3-CQ",
            "teamId": 200,
            "spell1Id": 4,
            "spell2Id": 21,
            "championId": 221,
            "profileIconId": 4571,
            "riotId": "붉은 새벽#KR1",
            "bot": 'false',
            "summonerId": "SjBgO5WM9Z-FtF7v0Qs4iEU42NZjO1LvSedK8kywoV-onDw",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8005,
                    9101,
                    9104,
                    8299,
                    8233,
                    8236,
                    5005,
                    5008,
                    5001
                ],
                "perkStyle": 8000,
                "perkSubStyle": 8200
            }
        },
        {
            "puuid": "HktXMK4tc6vwnPPPWQzbTOp04oBJxW3rqMFxl5tO-70llOv7GGEtLBxLpkZLkovgiXZAF6HhlAgv1g",
            "teamId": 200,
            "spell1Id": 14,
            "spell2Id": 4,
            "championId": 12,
            "profileIconId": 6582,
            "riotId": "처인구보안관빵야#KR1",
            "bot": 'false',
            "summonerId": "9352mQo8HjHUBqwf7wmr0etFN-LIhBsFJzIhoS4k3Ek6PRA",
            "gameCustomizationObjects": [],
            "perks": {
                "perkIds": [
                    8439,
                    8463,
                    8444,
                    8242,
                    8347,
                    8306,
                    5007,
                    5010,
                    5011
                ],
                "perkStyle": 8400,
                "perkSubStyle": 8300
            }
        }
    ],
    "observers": {
        "encryptionKey": "QbH83pvwlSswZk+Aumq5n5J9LShB3Ctj"
    },
    "platformId": "KR",
    "bannedChampions": [
        {
            "championId": 30,
            "teamId": 100,
            "pickTurn": 1
        },
        {
            "championId": 238,
            "teamId": 100,
            "pickTurn": 2
        },
        {
            "championId": 910,
            "teamId": 100,
            "pickTurn": 3
        },
        {
            "championId": 53,
            "teamId": 100,
            "pickTurn": 4
        },
        {
            "championId": 54,
            "teamId": 100,
            "pickTurn": 5
        },
        {
            "championId": 55,
            "teamId": 200,
            "pickTurn": 6
        },
        {
            "championId": 166,
            "teamId": 200,
            "pickTurn": 7
        },
        {
            "championId": 517,
            "teamId": 200,
            "pickTurn": 8
        },
        {
            "championId": 350,
            "teamId": 200,
            "pickTurn": 9
        },
        {
            "championId": 68,
            "teamId": 200,
            "pickTurn": 10
        }
    ],
    "gameStartTime": 1716949017358,
    "gameLength": 407
}

# %%
players = []
for player in test_data['participants']:
    players.append(player['championId'])
    players.append('EMERALD')
    players.append(player['teamId'])
    players.extend(player['perks']['perkIds'][:6])
    # players.extend([, player['perks']['perkSubStyle']])
    players.insert(7, player['perks']['perkStyle'])
    players.append(player['perks']['perkSubStyle'])
    # players.insert(0, player['perks']['perkSubStyle'])
    # players.append( player['perks']['perkIds'])


# 타입에 따라 데이터 분리 및 인덱스 저장
numerical_indices = [i for i, x in enumerate(players) if isinstance(x, int)]
numerical_data = [x for x in players if isinstance(x, int)]

categorical_indices = [i for i, x in enumerate(players) if isinstance(x, str)]
categorical_data = [x for x in players if isinstance(x, str)]

# 숫자 데이터 스케일링
if numerical_data:
    numerical_data = np.array(numerical_data).reshape(-1, 1)
    scaler = StandardScaler()
    scaled_numerical_data = scaler.fit_transform(numerical_data).flatten()
else:
    scaled_numerical_data = []

# 문자 데이터 인코딩
if categorical_data:
    categorical_data = np.array(categorical_data).reshape(-1, 1)
    encoder = OrdinalEncoder()
    encoded_categorical_data = encoder.fit_transform(categorical_data).flatten()
else:
    encoded_categorical_data = []

# 원래 순서대로 결과를 재구성
processed_data = [None] * len(players)
for i, value in zip(numerical_indices, scaled_numerical_data):
    processed_data[i] = value

for i, value in zip(categorical_indices, encoded_categorical_data):
    processed_data[i] = value

# 결과 출력
print("Original Data:", players)
print("Processed Data:", processed_data)
# Out:
# Original Data: [131, 'EMERALD', 100, 8010, 9111, 9104, 8014, 8400, 8000, 8100, 8100, 8000, 8000, 8000, 8200, 8000, 8000, 8304, 8347, 8300, 10, 'EMERALD', 100, 8021, 9101, 9104, 8299, 8444, 8451, 8400, 117, 'EMERALD', 100, 8214, 8226, 8210, 8237, 8345, 8347, 8300, 67, 'EMERALD', 100, 8021, 8009, 9104, 8014, 8451, 8429, 8400, 498, 'EMERALD', 100, 8021, 8009, 9103, 8014, 8304, 8345, 8300, 41, 'EMERALD', 200, 8021, 9101, 9105, 8014, 8345, 8347, 8300, 163, 'EMERALD', 200, 8128, 8126, 8138, 8135, 8304, 8347, 8300, 84, 'EMERALD', 200, 8112, 8143, 8138, 8106, 8451, 8444, 8400, 221, 'EMERALD', 200, 8005, 9101, 9104, 8299, 8233, 8236, 8200, 12, 'EMERALD', 200, 8439, 8463, 8444, 8242, 8347, 8306, 8300]
# Processed Data: [-1.9953046391145564, 0.0, -2.0047310692935087, 0.4005290183036847, 0.7353193288529274, 0.7331907801028414, 0.4017453318751624, 0.5191195915227625, 0.3974882343749904, 0.42789607366193344, 0.42789607366193344, 0.3974882343749904, 0.3974882343749904, 0.3974882343749904, 0.45830391294887646, 0.3974882343749904, 0.3974882343749904, 0.4899280658072972, 0.5030034367006827, 0.4887117522358195, -2.0320981246517573, 0.0, -2.0047310692935087, 0.4038738806252484, 0.7322785449242332, 0.7331907801028414, 0.4884076738429501, 0.5324990408090174, 0.5346275895591035, 0.5191195915227625, -1.9995617366147282, 0.0, -2.0047310692935087, 0.4625610104490485, 0.46620995116348163, 0.4613446968775708, 0.4695548134850454, 0.5023952799149438, 0.5030034367006827, 0.4887117522358195, -2.0147656562582, 0.0, -2.0047310692935087, 0.4038738806252484, 0.4002249399108153, 0.7331907801028414, 0.4017453318751624, 0.5346275895591035, 0.527937864915976, 0.5191195915227625, -1.8837078689314755, 0.0, -2.0047310692935087, 0.4038738806252484, 0.4002249399108153, 0.7328867017099719, 0.4017453318751624, 0.4899280658072972, 0.5023952799149438, 0.4887117522358195, -2.022671694472805, 0.0, -1.9743232300065656, 0.4038738806252484, 0.7322785449242332, 0.7334948584957108, 0.4017453318751624, 0.5023952799149438, 0.5030034367006827, 0.4887117522358195, -1.9855741305427346, 0.0, -1.9743232300065656, 0.4364102686622775, 0.4358021118765386, 0.4394510525909718, 0.4385388174123635, 0.4899280658072972, 0.5030034367006827, 0.4887117522358195, -2.0095963235794194, 0.0, -1.9743232300065656, 0.4315450143763666, 0.44097144455531895, 0.4394510525909718, 0.42972054401915, 0.5346275895591035, 0.5324990408090174, 0.5191195915227625, -1.9679375837563076, 0.0, -1.9743232300065656, 0.3990086263393376, 0.7322785449242332, 0.7331907801028414, 0.4884076738429501, 0.4683384999135677, 0.46925073509217596, 0.45830391294887646, -2.0314899678660185, 0.0, -1.9743232300065656, 0.5309786488446703, 0.5382765302735366, 0.5324990408090174, 0.4710752054493925, 0.5030034367006827, 0.4905362225930361, 0.4887117522358195]

# %%
loaded_model = TabularModel.load_model("/Users/gim-yeonghyeon/Downloads/student_model.pth")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 loaded_model = TabularModel.load_model("/Users/gim-yeonghyeon/Downloads/student_model.pth")
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/pytorch_tabular/tabular_model.py:427, in TabularModel.load_model(cls, dir, map_location, strict)
#     425     logger = None
#     426 if os.path.exists(os.path.join(dir, "callbacks.sav")):
# --> 427     callbacks = joblib.load(os.path.join(dir, "callbacks.sav"))
#     428     # Excluding Gradient Accumulation Scheduler Callback as we are creating
#     429     # a new one in trainer
#     430     callbacks = [c for c in callbacks if not isinstance(c, GradientAccumulationScheduler)]
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/joblib/numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/joblib/numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File /opt/anaconda3/lib/python3.11/pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File /opt/anaconda3/lib/python3.11/pickle.py:1590, in _Unpickler.load_reduce(self)
#    1588 args = stack.pop()
#    1589 func = stack[-1]
# -> 1590 stack[-1] = func(*args)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/torch/storage.py:381, in _load_from_bytes(b)
#     380 def _load_from_bytes(b):
# --> 381     return torch.load(io.BytesIO(b))
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/torch/serialization.py:1040, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1038     except RuntimeError as e:
#    1039         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1040 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/torch/serialization.py:1272, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1270 unpickler = UnpicklerWrapper(f, **pickle_load_args)
#    1271 unpickler.persistent_load = persistent_load
# -> 1272 result = unpickler.load()
#    1274 deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#    1276 if torch._guards.active_fake_mode() is None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/torch/serialization.py:1205, in _legacy_load.<locals>.persistent_load(saved_id)
#    1203     obj = cast(Storage, torch.UntypedStorage(nbytes))
#    1204     obj._torch_load_uninitialized = True
# -> 1205     obj = restore_location(obj, location)
#    1206 # TODO: Once we decide to break serialization FC, we can
#    1207 # stop wrapping with TypedStorage
#    1208 typed_storage = torch.storage.TypedStorage(
#    1209     wrap_storage=obj,
#    1210     dtype=dtype,
#    1211     _internal=True)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/torch/serialization.py:390, in default_restore_location(storage, location)
#     388 def default_restore_location(storage, location):
#     389     for _, _, fn in _package_registry:
# --> 390         result = fn(storage, location)
#     391         if result is not None:
#     392             return result
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/torch/serialization.py:265, in _cuda_deserialize(obj, location)
#     263 def _cuda_deserialize(obj, location):
#     264     if location.startswith('cuda'):
# --> 265         device = validate_cuda_device(location)
#     266         if getattr(obj, "_torch_load_uninitialized", False):
#     267             with torch.cuda.device(device):
#
# File ~/Library/Caches/pypoetry/virtualenvs/tabulr_transformers-9l9ugsAC-py3.11/lib/python3.11/site-packages/torch/serialization.py:249, in validate_cuda_device(location)
#     246 device = torch.cuda._utils._get_device_index(location, True)
#     248 if not torch.cuda.is_available():
# --> 249     raise RuntimeError('Attempting to deserialize object on a CUDA '
#     250                        'device but torch.cuda.is_available() is False. '
#     251                        'If you are running on a CPU-only machine, '
#     252                        'please use torch.load with map_location=torch.device(\'cpu\') '
#     253                        'to map your storages to the CPU.')
#     254 device_count = torch.cuda.device_count()
#     255 if device >= device_count:
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
import pandas as pd
columns = ['championId', 'tier', 'teamId', 'perk1', 'perk2', 'perk3', 'perk4', 'primaryStyle', 'perk5', 'perk6', 'subStyle', 'championId.1', 'tier.1', 'teamId.1', 'perk1.1', 'perk2.1', 'perk3.1', 'perk4.1', 'primaryStyle.1', 'perk5.1', 'perk6.1', 'subStyle.1', 'championId.2', 'tier.2', 'teamId.2', 'perk1.2', 'perk2.2', 'perk3.2', 'perk4.2', 'primaryStyle.2', 'perk5.2', 'perk6.2', 'subStyle.2', 'championId.3', 'tier.3', 'teamId.3', 'perk1.3', 'perk2.3', 'perk3.3', 'perk4.3', 'primaryStyle.3', 'perk5.3', 'perk6.3', 'subStyle.3', 'championId.4', 'tier.4', 'teamId.4', 'perk1.4', 'perk2.4', 'perk3.4', 'perk4.4', 'primaryStyle.4', 'perk5.4', 'perk6.4', 'subStyle.4', 'championId.5', 'tier.5', 'teamId.5', 'perk1.5', 'perk2.5', 'perk3.5', 'perk4.5', 'primaryStyle.5', 'perk5.5', 'perk6.5', 'subStyle.5', 'championId.6', 'tier.6', 'teamId.6', 'perk1.6', 'perk2.6', 'perk3.6', 'perk4.6', 'primaryStyle.6', 'perk5.6', 'perk6.6', 'subStyle.6', 'championId.7', 'tier.7', 'teamId.7', 'perk1.7', 'perk2.7', 'perk3.7', 'perk4.7', 'primaryStyle.7', 'perk5.7', 'perk6.7', 'subStyle.7', 'championId.8', 'tier.8', 'teamId.8', 'perk1.8', 'perk2.8', 'perk3.8', 'perk4.8', 'primaryStyle.8', 'perk5.8', 'perk6.8', 'subStyle.8', 'championId.9', 'tier.9', 'teamId.9', 'perk1.9', 'perk2.9', 'perk3.9', 'perk4.9', 'primaryStyle.9', 'perk5.9', 'perk6.9', 'subStyle.9']
df = pd.DataFrame([processed_data], columns=columns)
print(loaded_model.predict(df))
# 승리확률 30%
# Out:
#    1_probability_prediction
# 0                  0.356076
